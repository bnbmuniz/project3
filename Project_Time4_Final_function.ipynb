# %% [markdown]
# # Time4

# %% [markdown]
# iMDb + Netflix, HBO, (Amazon), Disney+

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import requests
import time
import random
import re
from dateutil import parser

# %%
# Load dataset
# netflix = pd.read_csv('titles_netflix.csv', index_col=False)
# disney = pd.read_csv('titles_disney.csv', index_col=False)
# hbo = pd.read_csv('hbo_shows_movies.csv', index_col=False)

# imdb = pd.read_csv('imdb_df.csv', index_col=False)

# %%
# Load dataset that is already clean
imdb = pd.read_csv('1imdb_final.csv', index_col=False)
imdb
# Out:
#      Unnamed: 0                 title           director duration  rating  \
# 0             0             Toy Story      John Lasseter     1:21     8.3
# 1             1               Amadeus       Milos Forman     2:40     8.3
# 2             2       American Beauty         Sam Mendes      2:2     8.3
# 3             3            Braveheart         Mel Gibson     2:58     8.3
# 4             4  Inglourious Basterds  Quentin Tarantino     2:33     8.3
# ..          ...                   ...                ...      ...     ...
# 258         258             Westworld                  -      1:2     8.6
# 259         259  Blackadder the Third                  -        3     8.6
# 260         260             Daredevil                  -       54     8.6
# 261         261            This Is Us                  -       45     8.6
# 262         262             Panchayat                  -       35     8.8
#
#                                     genre   type         cleaned_title  \
# 0    ['Animation', 'Adventure', 'Comedy']  movie             toy story
# 1         ['Biography', 'Drama', 'Music']  movie               amadeus
# 2                               ['Drama']  movie       american beauty
# 3       ['Biography', 'Drama', 'History']  movie            braveheart
# 4           ['Adventure', 'Drama', 'War']  movie  inglourious basterds
# ..                                    ...    ...                   ...
# 258        ['Drama', 'Mystery', 'Sci-Fi']   show             westworld
# 259                            ['Comedy']   show  blackadder the third
# 260          ['Action', 'Crime', 'Drama']   show             daredevil
# 261        ['Comedy', 'Drama', 'Romance']   show            this is us
# 262                   ['Comedy', 'Drama']   show             panchayat
#
#     disney+ netflix  hbo
# 0       Yes      No   No
# 1        No      No   No
# 2        No      No   No
# 3        No      No   No
# 4        No     Yes   No
# ..      ...     ...  ...
# 258      No      No  Yes
# 259      No      No   No
# 260     Yes      No   No
# 261      No      No   No
# 262      No      No   No
#
# [263 rows x 11 columns]

# %%
# Check and clean dataset

# %%
# netflix

# %%
# hbo = hbo.rename({'0':'title'}, axis=1)
# hbo

# %%
# disney

# %%
imdb.drop(columns='Unnamed: 0', inplace=True)
imdb
# Out:
#                     title           director duration  rating  \
# 0               Toy Story      John Lasseter     1:21     8.3
# 1                 Amadeus       Milos Forman     2:40     8.3
# 2         American Beauty         Sam Mendes      2:2     8.3
# 3              Braveheart         Mel Gibson     2:58     8.3
# 4    Inglourious Basterds  Quentin Tarantino     2:33     8.3
# ..                    ...                ...      ...     ...
# 258             Westworld                  -      1:2     8.6
# 259  Blackadder the Third                  -        3     8.6
# 260             Daredevil                  -       54     8.6
# 261            This Is Us                  -       45     8.6
# 262             Panchayat                  -       35     8.8
#
#                                     genre   type         cleaned_title  \
# 0    ['Animation', 'Adventure', 'Comedy']  movie             toy story
# 1         ['Biography', 'Drama', 'Music']  movie               amadeus
# 2                               ['Drama']  movie       american beauty
# 3       ['Biography', 'Drama', 'History']  movie            braveheart
# 4           ['Adventure', 'Drama', 'War']  movie  inglourious basterds
# ..                                    ...    ...                   ...
# 258        ['Drama', 'Mystery', 'Sci-Fi']   show             westworld
# 259                            ['Comedy']   show  blackadder the third
# 260          ['Action', 'Crime', 'Drama']   show             daredevil
# 261        ['Comedy', 'Drama', 'Romance']   show            this is us
# 262                   ['Comedy', 'Drama']   show             panchayat
#
#     disney+ netflix  hbo
# 0       Yes      No   No
# 1        No      No   No
# 2        No      No   No
# 3        No      No   No
# 4        No     Yes   No
# ..      ...     ...  ...
# 258      No      No  Yes
# 259      No      No   No
# 260     Yes      No   No
# 261      No      No   No
# 262      No      No   No
#
# [263 rows x 10 columns]

# %%
# imdb.duration.unique()

# %%
# Convert hh:mm into minutes
def changing_time(row):
    if ":" in row:
        ti_li=row.split(":")
        if len(ti_li[1])!=1:
            row = (int(ti_li[0])*60)+int(ti_li[1])
            return row 
        elif len(ti_li[1])==1:
            row = (int(ti_li[0])*60)+(int(ti_li[1])*10)
            return row
    elif len(row)==1:
        return int(row)*60
    else:
        return int(row)

# %%
# Save the duration in minutes in a new column
imdb['duration_min'] = imdb['duration'].apply(changing_time)
imdb
# Out:
#                     title           director duration  rating  \
# 0               Toy Story      John Lasseter     1:21     8.3
# 1                 Amadeus       Milos Forman     2:40     8.3
# 2         American Beauty         Sam Mendes      2:2     8.3
# 3              Braveheart         Mel Gibson     2:58     8.3
# 4    Inglourious Basterds  Quentin Tarantino     2:33     8.3
# ..                    ...                ...      ...     ...
# 258             Westworld                  -      1:2     8.6
# 259  Blackadder the Third                  -        3     8.6
# 260             Daredevil                  -       54     8.6
# 261            This Is Us                  -       45     8.6
# 262             Panchayat                  -       35     8.8
#
#                                     genre   type         cleaned_title  \
# 0    ['Animation', 'Adventure', 'Comedy']  movie             toy story
# 1         ['Biography', 'Drama', 'Music']  movie               amadeus
# 2                               ['Drama']  movie       american beauty
# 3       ['Biography', 'Drama', 'History']  movie            braveheart
# 4           ['Adventure', 'Drama', 'War']  movie  inglourious basterds
# ..                                    ...    ...                   ...
# 258        ['Drama', 'Mystery', 'Sci-Fi']   show             westworld
# 259                            ['Comedy']   show  blackadder the third
# 260          ['Action', 'Crime', 'Drama']   show             daredevil
# 261        ['Comedy', 'Drama', 'Romance']   show            this is us
# 262                   ['Comedy', 'Drama']   show             panchayat
#
#     disney+ netflix  hbo  duration_min
# 0       Yes      No   No            81
# 1        No      No   No           160
# 2        No      No   No           140
# 3        No      No   No           178
# 4        No     Yes   No           153
# ..      ...     ...  ...           ...
# 258      No      No  Yes            80
# 259      No      No   No           180
# 260     Yes      No   No            54
# 261      No      No   No            45
# 262      No      No   No            35
#
# [263 rows x 11 columns]

# %%
# Add Netlix to the df
# netflix_list = list(netflix['Netflix Tiles'])
# def streaming_netflix(row):
#         if row in netflix_list:
#             return 'Yes'
#         else:
#             return 'No'

# imdb['Netflix']=imdb['title'].apply(streaming_netflix)
# imdb[imdb['Netflix'] == 'Yes']#.head()

# %%
# Add HBO to the df
# hbo_list = list(hbo['title'])
# def streaming_hbo(row):
#         if row in hbo_list:
#             return 'Yes'
#         else:
#             return 'No'

# imdb['HBO']=imdb['title'].apply(streaming_hbo)
# # imdb.head()

# %%
# Add Disney to the df
# disney_list = list(disney['Disney Titles'])
# def streaming_disney(row):
#         if row in disney_list:
#             return 'Yes'
#         else:
#             return 'No'

# imdb['Disney+']=imdb['title'].apply(streaming_disney)
# # imdb.head()
# # imdb[imdb['Disney+'] == 'Yes']

# %%
imdb = imdb[['type',"title", "director", "duration", 'duration_min', 'genre', 
             'hbo','disney+', 'netflix', 'rating']]
# imdb = imdb.rename(columns={'HBO':'hbo','Disney+':'disney+', 'Netflix':'netflix'})
imdb.head()
# Out:
#     type                 title           director duration  duration_min  \
# 0  movie             Toy Story      John Lasseter     1:21            81
# 1  movie               Amadeus       Milos Forman     2:40           160
# 2  movie       American Beauty         Sam Mendes      2:2           140
# 3  movie            Braveheart         Mel Gibson     2:58           178
# 4  movie  Inglourious Basterds  Quentin Tarantino     2:33           153
#
#                                   genre hbo disney+ netflix  rating
# 0  ['Animation', 'Adventure', 'Comedy']  No     Yes      No     8.3
# 1       ['Biography', 'Drama', 'Music']  No      No      No     8.3
# 2                             ['Drama']  No      No      No     8.3
# 3     ['Biography', 'Drama', 'History']  No      No      No     8.3
# 4         ['Adventure', 'Drama', 'War']  No      No     Yes     8.3

# %%
# Create a function that take the input of time and convert it into minutes

# time_input = input('How much time you have: ').lower().strip().replace(' ', '')

def get_time(user_input):
    if ':' in user_input:
        hour = int(parser.parse(user_input).hour)
        min = int(parser.parse(user_input).minute)
        total_time = hour * 60 + min

    elif ('h' in user_input) & ('m' in user_input):
        user_input = re.sub('m.*', 'm', user_input)
        hour = int(parser.parse(user_input).hour)
        min = int(parser.parse(user_input).minute)
        total_time = hour * 60 + min

    elif 'h' in user_input:
        if user_input.index('h') != user_input[-1]:
            hour = int(parser.parse(user_input).hour)
            min = int(parser.parse(user_input).minute)
            total_time = hour * 60 + min
        else:
            hour = int(parser.parse(user_input).hour)
            total_time = hour * 60

    elif 'm' in user_input:
        user_input = re.sub('m.*', 'm', user_input)
        min = int(parser.parse(user_input).minute)
        total_time = min

    elif ((len(user_input) > 1) |(len(user_input) == 1)) & (re.search('[a-zA-Z]', user_input) == None):
        what = input("do you mean hours or min: ").strip()[0]
        if what == 'h':
            hour = int(user_input)
            total_time = hour * 60
        else:
            min = int(user_input)
            total_time = min
    return total_time

# print(get_time(time_input))

# %%
# Create a funtion that takes input of duration, genre and platform 
# and returns top 10 movies and shows from iMDb

def time4():
    # Define inputs
    a = input('How much time for a good time do you have? ').lower().strip().replace(' ', '')
    time_input = get_time(a)
    platform_input = input("Which platform you use? HBO, Netflix, Disney+").lower().strip()
    genre_input = input('What do you feel like watching? ').capitalize().strip()

    # Filter the df according to the inputs
    select_genre = imdb['genre'].str.contains(f'{genre_input}', na=False)
    select_dur = imdb['duration_min'] <= int(time_input)
    select_platform = imdb[f'{platform_input}'] == 'Yes'
    
    # Output top10
    selection = imdb[(select_genre) & (select_dur) & (select_platform)]
    selection = selection.sort_values(by='rating', axis=0, ascending=False).head(10)
    return selection.reset_index().drop(columns='index')

# %%
#youtube function
# Goggle API key
api_key = "AIzaSyA9Tb_efqIGXwKaDmZWN2nz5kXw_Qg1cmI"

from apiclient.discovery import build
import requests
import webbrowser
youtube = build('youtube','v3',developerKey = api_key)

def get_trailer(movie_show):
    trail = input('Do you want to watch the trailer? ').lower()
    if (trail == 'yes') | (trail == 'y'):
        request = youtube.search().list(q=f'{movie_show}+trailer',part='snippet',type='video')
        res = request.execute()
        video_id = res['items'][0]['id']['videoId']
        url_yt = f'https://www.youtube.com/watch?v={video_id}'
        print(url_yt)
        return webbrowser.open_new(url_yt)
    elif (trail == 'no') | (trail == 'n'):
        print('Enjoy your time! See you next time')
    else:
        print('Try again')
        get_trailer(movie_show)

# %%
movie_table = time4()
while movie_table.shape[0] == 0:
        display('No movies. Try again')
        movie_table = time4()
else:
    display(movie_table)
    movie = input('Which one you wanna watch? ')
    get_trailer(movie)
